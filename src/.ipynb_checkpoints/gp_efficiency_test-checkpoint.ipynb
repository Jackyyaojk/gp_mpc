# %%
# %load_ext autoreload
# %autoreload 2
import control
from gp_model import gp_model
from helper_fns import *

gp_params = yaml_load('../config/gp_params.yaml')
mpc_params = yaml_load('../config/mpc_params.yaml')
gp_models = gp_model(gp_params, rotation = True)
models, modes = gp_models.load_models(try_reload = False)

test_pt_eu = np.array([1.0, 0.05, 0.2, -1.67, 3.09, -1.8])
test_pt = eulerpose_to_rotpose(test_pt_eu)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading mode polish with {'data/polish_flat/2.bag', 'data/polish_flat/1.bag', 'data/polish_flat/3.bag'}
# Loading ros bag data/polish_flat/2.bag  with 3295 msgs
# Loading ros bag data/polish_flat/1.bag  with 4429 msgs
# Loading ros bag data/polish_flat/3.bag  with 2301 msgs
# Total of 7029 messages after trim
# (0.8307562866210938, 0.08977883911132813, 0.33884521484375, 1.2275376309083366, 1.5628076406872176, 3.136305476293907)
# -0.407348
# 1.99034
# [2.50477397 1.77464926 2.53428698]
# -0.407348
# 1.99034
# (0.8846173095703125, 0.0891051025390625, 0.339035888671875, 1.2241516879022787, 1.5605892275017166, 3.1340457841115565)
# -0.406151
# 1.98903
# [2.4998638  1.76905682 2.53892704]
# -0.406151
# 1.98903
# (0.9429420776367188, 0.08804833984375, 0.339183837890625, 1.2206513621275328, 1.5569509499826621, 3.129723473667297)
# -0.404593
# 1.98733
# [2.49051984 1.76398109 2.5462935 ]
# -0.404593
# 1.98733
# (0.9901076049804688, 0.08882111358642578, 0.3392152709960938, 1.219172242459793, 1.5543386552723883, 3.125803034231071)
# -0.403529
# 1.98617
# [2.482336   1.76273874 2.55150848]
# -0.403529
# 1.98617
# (1.03488525390625, 0.0889788818359375, 0.33884304809570315, 1.2218155629967307, 1.5562520033553695, 3.119765115414543)
# -0.402152
# 1.98466
# [2.47355189 1.77270194 2.54845186]
# -0.402152
# 1.98466
# (1.0740245361328125, 0.10366631317138672, 0.34113507080078126, 1.22663202298069, 1.5533704630591962, 3.11857628030529)
# -0.40379
# 1.98645
# [2.46877363 1.78052191 2.5532059 ]
# -0.40379
# 1.98645
# (1.0961322021484374, 0.15689508056640625, 0.3437318115234375, 1.241898061279907, 1.5404349570272444, 3.122184863578224)
# -0.411913
# 1.99535
# [2.46282964 1.79814943 2.57425678]
# -0.411913
# 1.99535
# (1.10033740234375, 0.20542855834960938, 0.3375335998535156, 1.2557772584430502, 1.5306804637557028, 3.128972462240753)
# -0.419938
# 2.00417
# [2.4647947  1.81301749 2.58932222]
# -0.419938
# 2.00417
# (1.103759521484375, 0.2514973602294922, 0.33911532592773436, 1.2679452414497183, 1.5232375943077086, 3.136316128938255)
# -0.427156
# 2.01214
# [2.46979464 1.82589251 2.60020706]
# -0.427156
# 2.01214
# (1.100339111328125, 0.283703125, 0.3545991516113281, 1.2738452085219383, 1.5196041104786109, 3.1361816393033597)
# -0.42958
# 2.01482
# [2.46598974 1.83461237 2.6059851 ]
#  [ 1.09019202  0.31050287  0.41138904  2.47406829  1.7584523   2.60406843]
#  [ 1.09019202  0.31050308  0.41138889  2.47406817  1.75845246  2.60406865]
#  [ 1.09019202  0.31050287  0.41138904  2.4740672   1.75845252  2.60406896]
#  [ 1.09019202  0.31050308  0.41138892  2.47406835  1.75845308  2.60406815]
#  [ 1.09019202  0.3105032   0.41138901  2.47406817  1.75845246  2.60406865]
#  [ 0.90139484  0.08357564  0.33594403  2.4702817   1.8612662   2.54161646]
#  [ 0.96470715  0.08503931  0.33591229  2.46218898  1.86083159  2.54321589]
#  [ 1.02775281  0.08582159  0.3356665   2.4510623   1.86293214  2.5447799 ]
#  [ 1.07332129  0.11226468  0.33671371  2.43935172  1.87632488  2.55709586]
#  [ 1.08943726  0.16441682  0.33868808  2.43012984  1.89581673  2.57863516]
#  [ 1.09494312  0.21655609  0.33799673  2.42733841  1.9145469   2.59717198]
#  [ 1.09892468  0.25649048  0.33956143  2.42596888  1.92758922  2.60998377]
#  [ 1.09506189  0.28837689  0.36347974  2.41480902  1.9369509   2.61937371]
#  [ 1.0905072   0.2943877   0.3775994   2.40807029  1.93998563  2.62346229]
#  [ 1.09049121  0.29442599  0.3775549   2.40814506  1.94019896  2.62331262]
#  [ 1.09048926  0.29443176  0.37755603  2.40821768  1.9402215   2.62327901]
#  [ 1.09048926  0.29443207  0.37755975  2.40825505  1.94020799  2.62327697]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in <lambda>(self, name, value)
#    6289         __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290     __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291     __swig_getmethods__ = {}
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in <lambda>(self, name, value)
#    6289         __swig_setmethods__.update(getattr(_s, '__swig_setmethods__', {}))
# -> 6290     __setattr__ = lambda self, name, value: _swig_setattr(self, DM, name, value)
#    6291     __swig_getmethods__ = {}
#
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in _swig_setattr(self, class_type, name, value)
#      73 def _swig_setattr(self, class_type, name, value):
# ---> 74     return _swig_setattr_nondynamic(self, class_type, name, value, 0)
#      75
#
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in _swig_setattr_nondynamic(self, class_type, name, value, static)
#      57     if (name == "this"):
# ---> 58         if type(value).__name__ == 'SwigPyObject':
#      59             self.__dict__[name] = value
#
# SystemError: <class 'type'> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-29-c74e79f86592> in <module>
#       8 mpc_params = yaml_load('../config/mpc_params.yaml')
#       9 gp_models = gp_model(gp_params, rotation = True)
# ---> 10 models, modes = gp_models.load_models(try_reload = False)
#      11
#      12 test_pt_eu = np.array([1.0, 0.05, 0.2, -1.67, 3.09, -1.8])
#
# ~/git/gp-mpc/src/gp_model.py in load_models(self, try_reload)
#      89                 self.load_data(mode)
#      90                 self.build_model(mode)
# ---> 91                 self.validate_model(mode)
#      92                 with open(self.gp_params['model_path'], 'wb') as f:
#      93                     pickle.dump(self.models, f)
#
# ~/git/gp-mpc/src/gp_model.py in validate_model(self, mode)
#     165         print(self.state[mode])
#     166         if self.gp_params['plot']:
# --> 167             self.plot_models()
#     168             if self.rotation: self.plot_models(rot = True)
#     169         if self.gp_params['plot_data']:
#
# ~/git/gp-mpc/src/gp_model.py in plot_models(self, rot)
#     214             for xi, yi, zi in zip(x,y,z):
#     215                 test_pt[off:off+3] = np.array([xi,yi,zi])
# --> 216                 mu, cov = self.models[mode].predict(test_pt)
#     217                 mu = mu[off:off+3]
#     218                 min_cov = np.minimum(cov[off:off+3], min_cov)
#
# ~/git/gp-mpc/src/gp_mpc/gp_class.py in predict(self, x, cov)
#     106         else:
#     107             x_s = x
# --> 108         mean, cov = self.__predict(x_s, cov)
#     109         if self.__normalize:
#     110             mean = inv_normalize(mean, self.__meanY, self.__stdY)
#
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in __call__(self, *args, **kwargs)
#   13442       if len(args)>0:
#   13443     # Ordered inputs -> return tuple
# > 13444         ret = self.call(args)
#   13445         if len(ret)==0:
#   13446           return None
#
# ~/.local/lib/python3.6/site-packages/casadi/casadi.py in call(self, *args)
#   12322
#   12323         """
# > 12324         return _casadi.Function_call(self, *args)
#   12325
#   12326
#
# SystemError: <built-in function Function_call> returned a result with an error set

# %%
# %load_ext autoreload
# %autoreload 2
from helper_fns import *
eu1 = np.array([1.178458767867565, 1.5750399390341376, -3.13720775527019])
eu2 = np.array([1.1800346934408186, 1.5722888936312294, 3.1404767855045317])
print(((euler_to_quat(eu1))))
print(((euler_to_quat(eu2))))
print(rotvec_to_rotation(np.array([1.49708619, 0.99597059, 1.48638353])))
print(euler_to_rotation(np.array([1.1800346934408186, 1.5722888936312294, 3.1404767855045317])))
print(rotvec_to_rotation(np.array([2.5239453,  1.69202554, 2.52206465])))
#%timeit models['polish'].predict(test_pt, [])
# Out:
# [0.393404, -0.589975, -0.392494, -0.585757]
# [-0.392795, 0.587776, 0.394038, 0.587338]
#
# [[0.00567423, 0.00224456, 0.999981],
#  [0.924002, -0.382363, -0.00438484],
#  [0.382346, 0.92401, -0.0042436]]
#
# [[-0.000463246, 0.924619, 0.380892],
#  [0.00180508, -0.380891, 0.924618],
#  [0.999998, 0.00111587, -0.00149257]]
#
# [[-0.000463247, 0.924619, 0.380892],
#  [0.00180508, -0.380891, 0.924618],
#  [0.999998, 0.00111587, -0.00149256]]

# %%
# %timeit models['polish'].predict_fast(test_pt)
# Out:
# 369 µs ± 10.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
from gp_dynamics import GPDynamics
gpmodel = GPDynamics(N_p = 6, mpc_params = mpc_params, gp = models['left'])
dyn = gpmodel.MDS_system()
xk = ca.MX.sym('xk',24)
uk = ca.MX.sym('uk',6)
res = dyn(x=xk, u=uk, init_pose=test_pt, hum_kin_opti = [], imp_params = [] )
dyn_map = dyn.map(3)
res_map = dyn_map(x = ca.MX.sym('xk',24,3), u = ca.MX.sym('uk',6,3), hum_kin_opti = [], imp_params = [])
print(dyn_map)
w = []
w += [ca.horzsplit(res_map['xf'])]
print(ca.reshape(res_map['xf'], 24*3,1))
# Out:
# map3_F_int:(x[24x3],u[6x3],init_pose[6x3],hum_kin_opti[],imp_params[12x3])->(xf[24x3],st_cost[1x3],hum_force_cart[6x3],hum_force_joint[]) Map
# vec(map3_F_int(xk, uk, zeros(6x3), 0x0, zeros(12x3)){0})

# %%
import casadi as ca
q0 = ca.SX.sym('q0', 6)
from helper_fns import *
x = ca.SX.sym('x',6)
quat_to_rotvec(quat_quat_mult(xyz_to_quat(x[3:]), q0))
#xyz_to_quat(x[:3])
# Out:
# SX(@1=2, @2=cos((x_3/@1)), @3=cos((x_4/@1)), @4=cos((x_5/@1)), @5=(@3*@4), @6=sin((x_3/@1)), @7=sin((x_4/@1)), @8=sin((x_5/@1)), @9=(@7*@8), @10=((@2*@5)+(@6*@9)), @11=((@6*@5)-(@2*@9)), @12=(@7*@4), @13=(@3*@8), @14=((@2*@12)+(@6*@13)), @15=((@2*@13)-(@6*@12)), @16=((((@10*q0_0)-(@11*q0_1))-(@14*q0_2))-(@15*q0_3)), @17=0.99991, @18=(@16<@17), @19=acos(((@18?@16:0)+((!@18)?@17:0))), @20=(@1*@19), [((((((@10*q0_1)+(@11*q0_0))-(@14*q0_3))+(@15*q0_2))/sin(@19))*@20), ((((((@10*q0_2)+(@11*q0_3))+(@14*q0_0))-(@15*q0_1))/sin(@19))*@20), ((((((@10*q0_3)-(@11*q0_2))+(@14*q0_1))+(@15*q0_0))/sin(@19))*@20)])

# %%
# Test if hand optimizing XYZ->QUAT brings something
import casadi as ca
a = ca.SX.sym('a')
b = ca.SX.sym('b')
c = ca.SX.sym('c')
abc = ca.vertcat(a,b,c)

res1 = ca.sin(a)*ca.sin(b)*ca.sin(c)+ca.cos(a)*ca.cos(b)*ca.cos(c)
res2 = 0.25*(ca.sin(a-b-c)+ca.sin(a+b-c)+ca.sin(a-b+c)-ca.sin(a+b+c)
             +ca.cos(a-b-c)+ca.cos(a+b-c)+ca.cos(a-b+c)+ca.cos(a+b+c))

f1 = ca.Function('f1', [a, b, c], [res1])
jf1 = ca.Function('jf1', [a, b, c], [ca.gradient(res1, abc)])
f2 = ca.Function('f2', [a, b, c], [res2])
jf2 = ca.Function('jf2', [a, b, c], [ca.gradient(res2, abc)])

# %timeit f1(0.5, -0.1, 0.3)
# %timeit f2(0.5, -0.1, 0.3)


# %timeit jf1(0.5, -0.1, 0.3)
# %timeit jf2(0.5, -0.1, 0.3)
# Out:
# 27.7 µs ± 2.12 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 25.9 µs ± 411 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 26 µs ± 1.65 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 26.2 µs ± 780 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
