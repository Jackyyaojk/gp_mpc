# %%
# Set up helper functions
from sensor_msgs.msg import JointState
from std_msgs.msg import Float64MultiArray
import rosbag
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

def bag_loader(path, map_and_append_msg, topic_name = 'robot_state', normalize = ''):
    bag = rosbag.Bag(path)
    num_obs = bag.get_message_count(topic_name)
    if num_obs is 0:
        topic_name = '/'+topic_name
        num_obs = bag.get_message_count(topic_name)
    print('Loading ros bag {}  with {} msgs on topic {}'.format(path, num_obs, topic_name))

    msgs = {}
    t = []
    for _, msg, t_ros in bag.read_messages(topics=[topic_name]):
        t.append(t_ros.to_sec())
        map_and_append_msg(msg, msgs)
    t = [tt-t[0] for tt in t]

    msgs_in_order = {}
    for key in msgs.keys():
        t_in_order, el_in_order = zip(*sorted(zip(t,msgs[key])))
        msgs_in_order[key] = np.array(el_in_order).T
    msgs_in_order['t'] = t_in_order
    
    if normalize is not '':
        msgs_in_order[normalize] = (msgs_in_order[normalize].T-msgs_in_order[normlize][:,0]).T
        
    return msgs_in_order

def get_aligned_msgs(msgs1, msgs2):
    ''' 
    Select entries from msgs2 which occured most recently before msgs1
    '''
    aligned_msgs2 = {key:[] for key in msgs2.keys()}
    t2 = np.array(msgs2['t'])
    for t1 in msgs1['t']:
        last_before_t1 = np.where(t2<=t1)[0][-1] # find last time in t which is 
        for key in msgs2.keys():
            if key == 't': continue
            aligned_msgs2[key].append(msgs2[key][:,last_before_t1])

    for key in msgs2.keys():
        aligned_msgs2[key] = np.array(aligned_msgs2[key]).T
    
    return aligned_msgs2

def map_robot_state(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('pos', 'vel', 'force'):
            prev_msgs[el] = []
    prev_msgs['pos'].append(msg.position)
    prev_msgs['vel'].append(msg.velocity)
    prev_msgs['force'].append(msg.effort)
    return prev_msgs
    
def map_impedance_gains(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('K', 'B', 'M', 'Fd'):
            prev_msgs[el] = []
    prev_msgs['K'].append(msg.position)
    prev_msgs['B'].append(msg.velocity)
    prev_msgs['M'].append(msg.effort[:len(msg.position)])
    prev_msgs['Fd'].append(msg.effort[len(msg.position):])

def map_delta_impedance_gains(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('dK', 'dB', 'dM', 'Fd'):
            prev_msgs[el] = []
    prev_msgs['dK'].append(msg.position)
    prev_msgs['dB'].append(msg.velocity)
    prev_msgs['dM'].append(msg.effort[:len(msg.position)])
    prev_msgs['Fd'].append(msg.effort[len(msg.position):])
    
def plot_model_cov(model_path, ext = 0.05):
    import pickle
    from gp_model import gp_model
    from mpl_toolkits.mplot3d import axes3d
    import matplotlib.pyplot as plt
    
    with open(model_path, 'rb') as f:
        models = pickle.load(f)
        modes = list(models.keys())
        print('Loaded models for {}'.format(modes))

    state_bounds = [np.full(3,1e10), np.full(3,-1e10)]
    for mode in modes:
        current_range = models[mode].get_xrange()
        state_bounds = [np.minimum(state_bounds[0],current_range[0]),
                        np.maximum(state_bounds[1],current_range[1])]

    fig2 = plt.figure(dpi=200)
    ax2 = fig2.gca(projection='3d')
    max_force = np.zeros((3,1))
    min_cov = np.full((3,1), 1e10)
    max_cov = np.zeros((3,1))
    exp = ext
    off = 0
    x, y, z = np.meshgrid(np.linspace(state_bounds[0][0+off]-exp, state_bounds[1][0+off]+exp, 5),
                          np.linspace(state_bounds[0][1+off]-exp, state_bounds[1][1+off]+exp, 5),
                          np.linspace(state_bounds[0][2+off]-exp, state_bounds[1][2+off]+exp, 5))
    x = x.flatten()
    y = y.flatten()
    z = z.flatten()
    offset = 0.0
    colors = ['r','g','b']
    for mode in modes:
        means = []
        covs   = []
        c = colors.pop()
        test_pt = models[mode].get_mean_state()
        for xi, yi, zi in zip(x,y,z):
            test_pt[off:off+3] = np.array([xi,yi,zi])
            mu, cov = models[mode].predict(test_pt)
            covs.append(0.5*np.min(np.diag(cov)))
        ax2.scatter(x+offset, y+offset, z+offset, s=covs, color = c)
        offset += 0.02
    print(covs)
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.set_zlabel('Z')
    ax2.set_title('GP for {}'.format(mode))
    return fig2, ax2
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.

# %%
# Plotting rail assembly over position
# %matplotlib

#_2 
baggies = [ '../data/rail_valid_1_2.bag', '../data/rail_valid_2_2.bag', '../data/rail_valid_3_2.bag']
gp_model_path = 'GP_models.pkl'
scale_B = 0.00003
scale_M = 0.00005

fig, ax = plot_model_cov(gp_model_path)

#fig = plt.figure(figsize=(8,8))
#ax = fig.add_subplot(projection="3d")
fig.suptitle("Rail assembly with GP-MPC")

for bag in baggies:
    imp_msgs = bag_loader(bag, map_impedance_gains, topic_name = 'impedance_gains_sim')
    state_msgs = bag_loader(bag, map_robot_state, topic_name = 'robot_state')

    state_msgs_aligned = get_aligned_msgs(imp_msgs, state_msgs)

    p = state_msgs_aligned['pos']
    B = imp_msgs['B']
    M = imp_msgs['M']
    subsample_rate = 10
    skipcnt = 0
    for p, B, M  in zip(state_msgs_aligned['pos'].T, imp_msgs['B'].T, imp_msgs['M'].T):
        if skipcnt > subsample_rate:
            skipcnt = 0
        else:
            skipcnt += 1
            continue

        line_damp = ax.plot([p[0]-scale_B*B[1], p[0]+scale_B*B[1]],
                [p[1], p[1]],
                [p[2], p[2]],'r', label = 'Damping')[0]
        ax.plot([p[0], p[0]],
                [p[1]-scale_B*B[0], p[1]+scale_B*B[0]],
                [p[2], p[2]],'r')
        ax.plot([p[0], p[0]],
                [p[1], p[1]],
                [p[2]-scale_B*B[2], p[2]+scale_B*B[2]],'r')
        p = p + 0.0005*np.ones(6)
        line_mass = ax.plot([p[0]-scale_M*M[1], p[0]+scale_M*M[1]],
                [p[1], p[1]],
                [p[2], p[2]],'b', label = 'Mass')[0]
        ax.plot([p[0], p[0]],
                [p[1]-scale_M*M[0], p[1]+scale_M*M[0]],
                [p[2], p[2]],'b')
        ax.plot([p[0], p[0]],
                [p[1], p[1]],
                [p[2]-scale_M*M[2], p[2]+scale_M*M[2]],'b')

plt.legend(handles=[line_damp, line_mass],labels=['Damping', 'Mass'])
plt.show()
# Out:
# Using matplotlib backend: GTK3Agg
# Loaded models for ['rail']
# /home/hanikevi/.local/lib/python3.6/site-packages/matplotlib/collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# [10.37355309313134, 10.329251332850188, 9.941533842853097, 9.286675286111823, 9.683714238888026, 10.372695068038782, 10.312091109876619, 9.806240243762474, 8.977741228714466, 9.498455612109897, 10.373353746343831, 10.34090501862215, 10.087459011562137, 9.68745690130819, 9.949806766376481, 10.374352279701903, 10.367395276224972, 10.318673270500176, 10.245185652298447, 10.296066866104642, 10.374818053875588, 10.374175916086976, 10.370645939187938, 10.365571506860155, 10.369388693946672, 10.344430233576608, 10.130889780298377, 9.227201159192953, 8.430105314572357, 9.399387246619032, 10.275434727140329, 9.877048612702168, 8.575535727444066, 7.6428351632009415, 9.071152096357228, 10.219079691222179, 9.886156849612384, 9.193972933365421, 8.864372877746272, 9.702214077940836, 10.249078721919016, 10.111843649627732, 10.016626048945962, 10.035148085949277, 10.239589989277865, 10.318740996995077, 10.287530249651379, 10.31315570254196, 10.340373965302199, 10.3638980950446, 9.82400402868221, 9.236477720402071, 8.909216839454961, 9.340438868877913, 10.088697339600499, 7.9621970503300625, 6.124166060230019, 6.5608862791900115, 8.35498882564607, 9.893758372938521, 5.7832038547999955, 3.0970017917776795, 5.5234191965018855, 8.508831791839587, 9.9999993114829, 6.102510171448466, 4.2610280718382, 7.1735302214251515, 9.433581343277584, 10.211014991704383, 8.220123430760411, 7.602467142419563, 9.216920055102209, 10.096737658500208, 10.330409606458417, 8.75584912813293, 8.175381407015134, 9.260870729340922, 9.930915344396658, 10.23501662441492, 2.701618431600175, 0.0187635680707281, 5.615784148228883, 8.69968898807212, 9.79566789373022, -5.293078505475753, -10.486737661114624, 1.2751297930612218, 7.451920229046436, 9.355383646640735, -5.446382939004938, -9.739461053435303, 2.187766018956543, 7.977374719396689, 9.613841406966019, 1.6982256391638852, 0.02349120937284077, 6.645474229079725, 9.447640834005146, 10.130373411485019, 9.871456856101117, 9.73789177504876, 10.077700186370622, 10.166951980324102, 10.2627580035691, 7.870058753541166, 7.157862743522308, 8.934368557301749, 9.45476537870964, 9.855032262554657, 4.965008706500839, 3.466752742810936, 7.40936802832645, 8.71344962436031, 9.42814622561422, 4.520575139453748, 3.2026400840983227, 7.546132436350643, 9.09756488355331, 9.690617157681979, 6.971766254313683, 6.416516816742066, 9.005842578978102, 9.934631512576408, 10.175683447447915]
# Loading ros bag ../data/rail_valid_1_2.bag  with 538 msgs on topic /impedance_gains_sim
# Loading ros bag ../data/rail_valid_1_2.bag  with 2800 msgs on topic /robot_state
# Loading ros bag ../data/rail_valid_2_2.bag  with 1144 msgs on topic /impedance_gains_sim
# Loading ros bag ../data/rail_valid_2_2.bag  with 5615 msgs on topic /robot_state
# Loading ros bag ../data/rail_valid_3_2.bag  with 687 msgs on topic /impedance_gains_sim
# Loading ros bag ../data/rail_valid_3_2.bag  with 3582 msgs on topic /robot_state

# %%
### Comparing with and without variance in contact
# %matplotlib
baggies = [ #'contact_no_var_chance_40_0_9_mbk',
            #'contact_var_chance_40_0_9_mbk',
            #'contact_var_chance_40_0_95_mbk',
            'contact_var_chance_40_0_97_mbk',
            'contact_var_well_damped_2_mbk',
            #'contact_var_well_damped_4_mbk',
            'contact_var_no_chance_mbk',
            #'contact_var_gp_35_mbk', 
            #'contact_no_var_mbk',
          ]
path = '../data/contact_var/2022_05_10_contact_var_exp/'
fig, axs = plt.subplots(3, figsize=(10,8))
fig.suptitle("Contact with GP-MPC")
cols = ['r', 'b', 'k', 'r:', 'b:', 'k:']
for bag in baggies:
    col = cols.pop(0)
#    msgs_dimp = bag_loader(path+bag+'.bag', map_delta_impedance_gains, topic_name = '/delta_impedance_gains')
    imp_msgs = bag_loader(path+bag+'.bag', map_impedance_gains, topic_name = '/impedance_gains')
    state_msgs = bag_loader(path+bag+'.bag', map_robot_state, topic_name = '/robot_state')

    state_msgs_aligned = get_aligned_msgs(imp_msgs, state_msgs)

    ind = 2
    #plt.figure(figsize=(6,3), dpi= 100)
    
    axs[0].plot(0.57-state_msgs_aligned['pos'][ind], imp_msgs['Fd'][ind], col, label = bag)
    axs[1].plot(0.57-state_msgs_aligned['pos'][ind], imp_msgs['B'][ind], col)
    axs[2].plot(0.57-state_msgs_aligned['pos'][ind], imp_msgs['M'][ind], col)

axs[0].legend()
for i in range(3): axs[i].grid(True)
#for i in range(3): axs[i].set_xlim([0,6])
plt.xlabel('Position (meters)')
axs[0].set(ylabel='Fd (N)', title = 'Desired force')
axs[1].set(ylabel='dB (Nm/s))', title = 'Change imp damping')
axs[2].set(ylabel='dM (kg)', title = 'Change imp inertia')

plt.show()
# Out:
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_chance_40_0_97_mbk.bag  with 2388 msgs on topic /impedance_gains
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_chance_40_0_97_mbk.bag  with 2387 msgs on topic /robot_state
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_well_damped_2_mbk.bag  with 3064 msgs on topic /impedance_gains
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_well_damped_2_mbk.bag  with 3064 msgs on topic /robot_state
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_no_chance_mbk.bag  with 2175 msgs on topic /impedance_gains
# Loading ros bag ../data/contact_var/2022_05_10_contact_var_exp/contact_var_no_chance_mbk.bag  with 2175 msgs on topic /robot_state

# %%
# Plotting rail assembly over time
# %matplotlib

bag = 'rail_valid_3_4.bag'

fig, axs = plt.subplots(3, figsize=(10,8))
fig.suptitle("Rail assembly with GP-MPC")
cols = ['r', 'b', 'k', 'r:', 'b:', 'k:']
msgs = bag_loader(bag, map_delta_impedance_gains, topic_name = 'delta_impedance_gains')
dM = msgs['dM']
Fd = msgs['Fd']
dB = msgs['dB']
t = msgs['t']


dirs = ['X', 'Y', 'Z']
for ind in range(3):
    col = cols.pop(0)
#plt.figure(figsize=(6,3), dpi= 100)
    axs[0].plot(t, Fd[ind], col, label = dirs.pop(0))
    axs[1].plot(t, dB[ind], col)
    axs[2].plot(t, dM[ind], col)

axs[0].legend()
for i in range(3): axs[i].grid(True)
#for i in range(3): axs[i].set_xlim([0,6])
plt.xlabel('Time (sec)')
axs[0].set(ylabel='Fd (N)', title = 'Desired force')
axs[1].set(ylabel='dB (Nm/s))', title = 'Change imp damping')
axs[2].set(ylabel='dM (kg)', title = 'Change imp inertia')

plt.show()
# Out:
# Loading ros bag rail_valid_3_4.bag  with 719 msgs on topic /delta_impedance_gains

# %%
from src.gp_model import gp_model
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-7d835f6e3f11> in <module>
# ----> 1 from src.gp_model import gp_model
#
# ~/gitlab-ipk/gp-mpc-impedance-control/src/gp_model.py in <module>
#      13
#      14 # Custom classes
# ---> 15 from gp_mpc import GP
#      16 from gp_sparse import gp_sparse
#      17 from helper_fns import msg_to_state, msg_to_obs, force_comp_to_world
#
# ModuleNotFoundError: No module named 'gp_mpc'
