# %%
# Set up helper functions
from sensor_msgs.msg import JointState
from std_msgs.msg import Float64MultiArray
import rosbag
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy

def bag_loader(path, map_and_append_msg, topic_name = 'robot_state', normalize = ''):
    bag = rosbag.Bag(path)
    num_obs = bag.get_message_count(topic_name)
    if num_obs is 0:
        topic_name = '/'+topic_name
        num_obs = bag.get_message_count(topic_name)
    print('Loading ros bag {}  with {} msgs on topic {}'.format(path, num_obs, topic_name))

    msgs = {}
    t = []
    for _, msg, t_ros in bag.read_messages(topics=[topic_name]):
        t.append(t_ros.to_sec())
        map_and_append_msg(msg, msgs)
    t = [tt-t[0] for tt in t]

    msgs_in_order = {}
    for key in msgs.keys():
        t_in_order, el_in_order = zip(*sorted(zip(t,msgs[key])))
        msgs_in_order[key] = np.array(el_in_order).T
    msgs_in_order['t'] = t_in_order
    
    if normalize is not '':
        msgs_in_order[normalize] = (msgs_in_order[normalize].T-msgs_in_order[normlize][:,0]).T
        
    return msgs_in_order

def get_aligned_msgs(msgs1, msgs2):
    ''' 
    Select entries from msgs2 which occured most recently before msgs1
    '''
    aligned_msgs2 = {key:[] for key in msgs2.keys()}
    t2 = np.array(msgs2['t'])
    for t1 in msgs1['t']:
        last_before_t1 = np.where(t2<=t1)[0][-1] # find last time in t which is 
        for key in msgs2.keys():
            if key == 't': continue
            aligned_msgs2[key].append(msgs2[key][:,last_before_t1])

    for key in msgs2.keys():
        aligned_msgs2[key] = np.array(aligned_msgs2[key]).T
    
    return aligned_msgs2

def map_robot_state(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('pos', 'vel', 'force'):
            prev_msgs[el] = []
    prev_msgs['pos'].append(msg.position)
    prev_msgs['vel'].append(msg.velocity)
    prev_msgs['force'].append(msg.effort)
    return prev_msgs
    
def map_impedance_gains(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('K', 'B', 'M', 'Fd'):
            prev_msgs[el] = []
    prev_msgs['K'].append(msg.position)
    prev_msgs['B'].append(msg.velocity)
    prev_msgs['M'].append(msg.effort[:len(msg.position)])
    prev_msgs['Fd'].append(msg.effort[len(msg.position):])

def map_delta_impedance_gains(msg, prev_msgs):
    if len(prev_msgs) is 0:
        for el in ('dK', 'dB', 'dM', 'Fd'):
            prev_msgs[el] = []
    prev_msgs['dK'].append(msg.position)
    prev_msgs['dB'].append(msg.velocity)
    prev_msgs['dM'].append(msg.effort[:len(msg.position)])
    prev_msgs['Fd'].append(msg.effort[len(msg.position):])
    
def plot_model_cov(model_path, ext = 0.3):
    import pickle
    from src.gp_model import gp_model
    from mpl_toolkits.mplot3d import axes3d
    import matplotlib.pyplot as plt
    
    with open(model_path, 'rb') as f:
        models = pickle.load(f)
        modes = list(self.models.keys())
        print('Loaded models for {}'.format(modes))

    state_bounds = [np.full(6,1e10), np.full(6,-1e10)]
    for mode in modes:
        current_range = models[mode].get_xrange()
        state_bounds = [np.minimum(state_bounds[0],current_range[0]),
                        np.maximum(state_bounds[1],current_range[1])]

    fig2 = plt.figure(dpi=200)
    ax2 = fig2.gca(projection='3d')
    max_force = np.zeros((3,1))
    min_cov = np.full((3,1), 1e10)
    max_cov = np.zeros((3,1))
    exp = ext
    off = 0
    x, y, z = np.meshgrid(np.linspace(state_bounds[0][0+off]-exp, state_bounds[1][0+off]+exp, 5),
                          np.linspace(state_bounds[0][1+off]-exp, state_bounds[1][1+off]+exp, 5),
                          np.linspace(state_bounds[0][2+off]-exp, state_bounds[1][2+off]+exp, 5))
    x = x.flatten()
    y = y.flatten()
    z = z.flatten()
    offset = 0.0
    colors = ['r','g','b']
    for mode in self.modes:
        means = []
        covs   = []
        c = colors.pop()
        test_pt = np.mean(self.state[mode], axis = 0)
        for xi, yi, zi in zip(x,y,z):
            test_pt[off:off+3] = np.array([xi,yi,zi])
            mu, cov = self.models[mode].predict(test_pt[:self.state_dim])
            covs.append(0.5*np.linalg.norm(np.diag(cov)))
        ax2.scatter(x+offset, y+offset, z+offset, s=covs, color = c)
        offset += 0.02
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.set_zlabel('Z')
    ax2.set_title('GP for {}, rotation: {}'.format(mode, rot))
    return fig2, ax2
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.

# %%
# Plotting rail assembly over position
# %matplotlib

#_2 
baggies = [ 'rail_valid_1_2.bag', 'rail_valid_2_2.bag', 'rail_valid_3_2.bag']
gp_model_path = 'GP_models.pkl'
scale_B = 0.00003
scale_M = 0.00005

fig, ax = plot_model_cov(gp_model_path)

#fig = plt.figure(figsize=(8,8))
#ax = fig.add_subplot(projection="3d")
fig.suptitle("Rail assembly with GP-MPC")

for bag in baggies:
    imp_msgs = bag_loader(bag, map_impedance_gains, topic_name = 'impedance_gains_sim')
    state_msgs = bag_loader(bag, map_robot_state, topic_name = 'robot_state')

    state_msgs_aligned = get_aligned_msgs(imp_msgs, state_msgs)



    p = state_msgs_aligned['pos']
    B = imp_msgs['B']
    M = imp_msgs['M']
    subsample_rate = 10
    skipcnt = 0
    for p, B, M  in zip(state_msgs_aligned['pos'].T, imp_msgs['B'].T, imp_msgs['M'].T):
        if skipcnt > subsample_rate:
            skipcnt = 0
        else:
            skipcnt += 1
            continue

        line_damp = ax.plot([p[0]-scale_B*B[1], p[0]+scale_B*B[1]],
                [p[1], p[1]],
                [p[2], p[2]],'r', label = 'Damping')[0]
        ax.plot([p[0], p[0]],
                [p[1]-scale_B*B[0], p[1]+scale_B*B[0]],
                [p[2], p[2]],'r')
        ax.plot([p[0], p[0]],
                [p[1], p[1]],
                [p[2]-scale_B*B[2], p[2]+scale_B*B[2]],'r')
        p = p + 0.0005*np.ones(6)
        line_mass = ax.plot([p[0]-scale_M*M[1], p[0]+scale_M*M[1]],
                [p[1], p[1]],
                [p[2], p[2]],'b', label = 'Mass')[0]
        ax.plot([p[0], p[0]],
                [p[1]-scale_M*M[0], p[1]+scale_M*M[0]],
                [p[2], p[2]],'b')
        ax.plot([p[0], p[0]],
                [p[1], p[1]],
                [p[2]-scale_M*M[2], p[2]+scale_M*M[2]],'b')

plt.legend(handles=[line_damp, line_mass],labels=['Damping', 'Mass'])
plt.show()
# Out:
# Using matplotlib backend: GTK3Agg
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-8222f7331208> in <module>
#       8 scale_M = 0.00005
#       9
# ---> 10 fig, ax = plot_model_cov(gp_model_path)
#      11
#      12 #fig = plt.figure(figsize=(8,8))
#
# <ipython-input-1-a67b955f9991> in plot_model_cov(model_path, ext)
#      79 def plot_model_cov(model_path, ext = 0.3):
#      80     import pickle
# ---> 81     from src.gp_mpc import gp_mpc
#      82     from mpl_toolkits.mplot3d import axes3d
#      83     import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'gp_mpc'

# %%
### Comparing with and without variance in contact
# %matplotlib
baggies = [ 'no_var_no_chance_no_well_damped.bag',
            'no_var_chance_no_well_damped.bag',
            'no_var_no_chance_well_damped.bag',
            'var_no_chance_no_well_damped.bag',
            'var_chance_no_well_damped.bag',
            'var_no_chance_well_damped.bag',
            ]

fig, axs = plt.subplots(3, figsize=(10,8))
fig.suptitle("Contact with GP-MPC")
cols = ['r', 'b', 'k', 'r:', 'b:', 'k:']
for bag in baggies:
    col = cols.pop(0)
    msgs = bag_loader(bag, map_delta_impedance_gains, topic_name = 'delta_impedance_gains')
    
    ind = 2
    #plt.figure(figsize=(6,3), dpi= 100)
    
    axs[0].plot(msgs['t'], msgs['Fd'][ind], col, label = bag)
    axs[1].plot(msgs['t'], msgs['dB'][ind], col)
    axs[2].plot(msgs['t'], msgs['dM'][ind], col)

axs[0].legend()
for i in range(3): axs[i].grid(True)
for i in range(3): axs[i].set_xlim([0,6])
plt.xlabel('Time (sec)')
axs[0].set(ylabel='Fd (N)', title = 'Desired force')
axs[1].set(ylabel='dB (Nm/s))', title = 'Change imp damping')
axs[2].set(ylabel='dM (kg)', title = 'Change imp inertia')

plt.show()
# Out:
# Loading ros bag no_var_no_chance_no_well_damped.bag  with 147 msgs on topic /delta_impedance_gains
# Loading ros bag no_var_chance_no_well_damped.bag  with 125 msgs on topic /delta_impedance_gains
# Loading ros bag no_var_no_chance_well_damped.bag  with 74 msgs on topic /delta_impedance_gains
# Loading ros bag var_no_chance_no_well_damped.bag  with 133 msgs on topic /delta_impedance_gains
# Loading ros bag var_chance_no_well_damped.bag  with 98 msgs on topic /delta_impedance_gains
# Loading ros bag var_no_chance_well_damped.bag  with 108 msgs on topic /delta_impedance_gains

# %%
# Plotting rail assembly over time
# %matplotlib

bag = 'rail_valid_3_4.bag'

fig, axs = plt.subplots(3, figsize=(10,8))
fig.suptitle("Rail assembly with GP-MPC")
cols = ['r', 'b', 'k', 'r:', 'b:', 'k:']
msgs = bag_loader(bag, map_delta_impedance_gains, topic_name = 'delta_impedance_gains')
dM = msgs['dM']
Fd = msgs['Fd']
dB = msgs['dB']
t = msgs['t']


dirs = ['X', 'Y', 'Z']
for ind in range(3):
    col = cols.pop(0)
#plt.figure(figsize=(6,3), dpi= 100)
    axs[0].plot(t, Fd[ind], col, label = dirs.pop(0))
    axs[1].plot(t, dB[ind], col)
    axs[2].plot(t, dM[ind], col)

axs[0].legend()
for i in range(3): axs[i].grid(True)
#for i in range(3): axs[i].set_xlim([0,6])
plt.xlabel('Time (sec)')
axs[0].set(ylabel='Fd (N)', title = 'Desired force')
axs[1].set(ylabel='dB (Nm/s))', title = 'Change imp damping')
axs[2].set(ylabel='dM (kg)', title = 'Change imp inertia')

plt.show()
# Out:
# Loading ros bag rail_valid_3_4.bag  with 719 msgs on topic /delta_impedance_gains

# %%
# Acceleration compensation

import glob

paths = glob.glob('nj60_test/*.bag')
paths = [ 'nj60_test/13.bag', 'nj60_test/14.bag', 'nj60_test/15.bag']# 'nj60_test/13.bag', 'nj60_test/14.bag', 'nj60_test/15.bag']
names = [r'$K_l=0.02$, $\hat{P}=16$, $B_{fb} = 0$ TUSTIN',
         r'$K_l=0.02$, $\hat{P}=0\,\,$, $B_{fb} = 0$ TUSTIN', 
         r'$K_l=0.02$, $\hat{P}=0\,\,$, $B_{fb} = 0$ EULER', ]
start_times = [10.54, 10.18, 3.83]
start_times = [st+0.5 for st in start_times]
scales = [1.0, 1.0, 1.0]

num_points = 125
y_label = 'Force (N)'

plt.figure(figsize=(10,4), dpi= 100)
cols = list('grc')
for path, start_time, name, scale in zip(paths, start_times, names, scales):
    x, y, _= bag_loader(path)
    st_idx = next(i for i, t in enumerate(x) if t >= start_time)
    x = [t-x[st_idx] for t in x]
    y = [scale*y_pt for y_pt in y]
    print(max(y[st_idx:st_idx+num_points]))
    plt.plot(x[st_idx:st_idx+num_points], y[st_idx:st_idx+num_points], label=name, color = cols.pop())
plt.xlabel('Time (sec)')
plt.ylabel(y_label)
plt.legend()
plt.grid(True)
# Out:
# Loading ros bag nj60_test/13.bag  with 4625 msgs
# 66.38324163893208
# Loading ros bag nj60_test/14.bag  with 877 msgs
# 61.70473822616813
# Loading ros bag nj60_test/15.bag  with 1857 msgs
# 128.63431127537365

# %%
# FF and FB control comparison
import glob

paths = glob.glob('nj60_test/*.bag')
paths = ['nj60_test/2.bag', 'nj60_test/1.bag', 'nj60_test/3.bag']
names = [r'$K_l=0.0\,\,$, $B_{fb} = 0$',  
         r'$K_l=0.02$, $B_{fb} = 0$',
         r'$K_l=0.02$, $B_{fb} = 7.5e-6$',]
start_times = [26.85, 9.35, 5.3]
start_times = [st+0.5 for st in start_times]
scales = [1.65, 1.0, 1.0]#, 1.0]



num_points = 135
y_label = 'Force (N)'

plt.figure(figsize=(8,4), dpi= 200)

cols = list('rgb')
for path, start_time, name, scale in zip(paths, start_times, names, scales):
    x, y, z = bag_loader(path)
    st_idx = next(i for i, t in enumerate(x) if t >= start_time)
    x = [t-x[st_idx] for t in x]
    y = [scale*y_pt for y_pt in y]
    print(z[st_idx+num_points])
    print(max(y[st_idx:st_idx+num_points]))
    plt.plot(x[st_idx:st_idx+num_points], y[st_idx:st_idx+num_points], label=name, color = cols.pop())
plt.xlabel('Time (sec)')
plt.ylabel(y_label)
plt.legend()
plt.grid(True)
# Out:
# Loading ros bag nj60_test/2.bag  with 1855 msgs
# 0.9295336303710937
# 77.5178809244753
# Loading ros bag nj60_test/1.bag  with 1169 msgs
# 0.9292537841796875
# 72.50472559436774
# Loading ros bag nj60_test/3.bag  with 551 msgs
# 0.9291132202148438
# 58.14787168972599

# %%
paths = ['nj60_test/4.bag', 'nj60_test/13.bag']
names = ['Contact with pins', 'Contact with yellow table']
start_times = [3.82, 10.54]
scales = [1.65, 1.0]

num_points = 150
y_label = 'Force (N)'

plt.figure(figsize=(10,6), dpi= 100)

for path, start_time, name, scale in zip(paths, start_times, names, scales):
    x, y = bag_loader(path)
    st_idx = next(i for i, t in enumerate(x) if t >= start_time)
    x = [t-x[st_idx] for t in x]
    y = [scale*y_pt for y_pt in y]
    plt.plot(x[st_idx:st_idx+num_points], y[st_idx:st_idx+num_points], label=name)
plt.xlabel('Time (sec)')
plt.ylabel(y_label)
plt.legend()
plt.grid(True)
plt.savefig('fig4.png')
# Out:
# Loading ros bag nj60_test/4.bag  with 2046 msgs
# Loading ros bag nj60_test/13.bag  with 4625 msgs

# %%
# Compare contact dynamics, magazine
#u1, ym1 = import_csv('nj60_magazine_contact/yellow_feet_imco.csv')


u1, ym1 = import_csv('nj60_magazine_contact/flex_jt_imco.csv')
u2, ym2 = import_csv('nj60_magazine_contact/yellow_surf_imco.csv')
u3, ym3 = import_csv('nj60_magazine_contact/yellow_feet_imco.csv')
u1c, ym1c = import_csv('nj60_magazine_contact/flex_jt_coll.csv')
u2c, ym2c = import_csv('nj60_magazine_contact/yellow_surf_coll.csv')


plt.figure()
plt.figure(figsize=(8,3), dpi = 200)

#plt.subplot(2,1,1)
plt.plot(ym1[0:1000], 'b', label='Stiff surface, Compliant joints')
plt.plot(ym3[0:1000], 'k', label = 'Stiff surface, Stiff joints')
plt.plot(ym2[0:1000], 'r', label = 'Compliant surface, Stiff joints')
#plt.plot(ym1c[0:1000],'b:', label='w/ collision detection')
#plt.plot(ym2c[0:1000],'r:',label = 'w/ collision detection')
plt.ylabel('Force (N)')
plt.grid(True)
'''
plt.subplot(2,1,2)
plt.plot(u1[9:1000], 'b', label='Stiff surface, Compliant joints')
plt.plot(u3[9:1000], 'k', label = 'Stiff surface, Stiff joints')
plt.plot(u2[9:1000], 'r', label = 'Compliant surface, Stiff joints')
#plt.plot(u1c[9:1000],'b:', label='w/ collision detection')
#plt.plot(u2c[9:1000],'r:',label = 'w/ collision detection')
'''
plt.grid(True)
plt.legend()
print(max(ym1))
print(max(ym2))
print(max(ym3))
plt.xlabel('Time (ms)')
plt.ylabel('Velocity (m/s)')
plt.show()
# Out:
# 34.397
# 39.623
# 55.62

# %%
# Loading the variable impedance bags for RA-L paper
from sensor_msgs.msg import JointState
from std_msgs.msg import Float64MultiArray
import rosbag
import numpy as np
import matplotlib.pyplot as plt

def bag_loader(path, topic_name = 'robot_state'):
    bag = rosbag.Bag(path)
    topic_name = 'robot_state'
    num_obs = bag.get_message_count(topic_name)
    if num_obs is 0:
        topic_name = '/'+topic_name
        num_obs = bag.get_message_count(topic_name)
    print('Loading ros bag {}  with {} msgs'.format(path, num_obs))

    x = []
    y = [] 
    z = []
    for _, msg, t_ros in bag.read_messages(topics=[topic_name]):
        #x.append(t_ros.to_sec())
        x.append(msg.header.stamp.to_sec())
        y.append(msg.effort[2])
        z.append(msg.position[2])
    
    x, y, z = zip(*sorted(zip(x, y, z)))
    x = [t-x[0] for t in x]
    return x, y, z

t_imp, b_imp =
# Out:
# Loading ros bag contact_var/0.bag  with 5810 msgs

# %%
# Loading the variable impedance
from sensor_msgs.msg import JointState
from std_msgs.msg import Float64MultiArray
import rosbag
import numpy as np
import matplotlib.pyplot as plt

def bag_loader(path, topic_name = 'robot_state'):
    bag = rosbag.Bag(path)
    topic_name = 'robot_state'
    num_obs = bag.get_message_count(topic_name)
    if num_obs is 0:
        topic_name = '/'+topic_name
        num_obs = bag.get_message_count(topic_name)
    print('Loading ros bag {}  with {} msgs'.format(path, num_obs))

    x = []
    y = [] 
    z = []
    for _, msg, t_ros in bag.read_messages(topics=[topic_name]):
        #x.append(t_ros.to_sec())
        x.append(msg.header.stamp.to_sec())
        y.append(msg.effort[2])
        z.append(msg.position[2])
    
    x, y, z = zip(*sorted(zip(x, y, z)))
    x = [t-x[0] for t in x]
    return x, y, z

t_imp, b_imp =
